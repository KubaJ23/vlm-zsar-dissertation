# %% [markdown]
# # Analyse Results of Experiment

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

project_root = Path("..")
sys.path.append(str(project_root))

# %% [markdown]
# ## Initialise Results Analyser to Calculate Accuracies

# %%
from src.utils.results_analysis import ResultsAnalyser
from src.utils.constants import RESULTS_DIR

results_dir = RESULTS_DIR / "activitynet_all_combinations_16"

results_analyser = ResultsAnalyser(results_dir)

# %%
results_analyser.print_results_table()
# Out:
#                                                     model  Class Accuracies  Top-1  Top-5 Brier Score    ECE
#     UniformSampler16, QueryScoringAggregator, MPVRPrompts              74.0   74.9   94.2    0.994009 74.32%
#          MGSampler16, QueryScoringAggregator, MPVRPrompts              73.3   74.5   94.4    0.993942 73.92%
#                UniformSampler16, MeanPooling, MPVRPrompts              72.3   73.2   93.0    0.993989 72.61%
#                     MGSampler16, MeanPooling, MPVRPrompts              71.0   72.5   93.0    0.993958 71.91%
# UniformSampler16, QueryScoringAggregator, TemplatePrompts              70.3   71.1   91.8    0.994099 70.51%
#      MGSampler16, QueryScoringAggregator, TemplatePrompts              69.2   70.8   92.7    0.994060 70.20%
#                 MGSampler16, MeanPooling, TemplatePrompts              68.3   69.6   91.8    0.994070 69.10%
#            UniformSampler16, MeanPooling, TemplatePrompts              68.6   69.5   91.2    0.994098 69.00%

# %%
results_analyser.show_accuracy_comparison_plot()

# %%
results_analyser.plot_confused_classes_table("UniformSampler16, QueryScoringAggregator, MPVRPrompts")

# %%
results_analyser.plot_calibration_wilcoxon_heatmap()
# Out:
# friedman test p-value: 0.0000

# %%
results_analyser.plot_accuracy_mcnemar_heatmap()
