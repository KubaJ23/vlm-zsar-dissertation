# %% [markdown]
# # Analyse Results of Experiment

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

project_root = Path("..")
sys.path.append(str(project_root))

# %% [markdown]
# ## Initialise Results Analyser to Calculate Accuracies

# %%
from src.utils.results_analysis import ResultsAnalyser
from src.utils.constants import RESULTS_DIR

results_dir = RESULTS_DIR / "activitynet_all_combinations_120"

results_analyser = ResultsAnalyser(results_dir)

# %%
results_analyser.print_results_table()
# Out:
#                                                      model  Class Accuracies  Top-1  Top-5  Top-1 Error  Top-5 Error Brier Score    ECE
#     UniformSampler120, QueryScoringAggregator, MPVRPrompts              75.1   76.2   94.4          2.6          1.4    0.993957 75.63%
#          MGSampler120, QueryScoringAggregator, MPVRPrompts              75.0   76.1   94.0          2.7          1.5    0.993943 75.52%
#                UniformSampler120, MeanPooling, MPVRPrompts              73.9   74.8   93.6          2.7          1.5    0.993958 74.22%
#                     MGSampler120, MeanPooling, MPVRPrompts              73.4   74.1   93.1          2.7          1.6    0.993955 73.51%
# UniformSampler120, QueryScoringAggregator, TemplatePrompts              72.1   73.0   92.7          2.8          1.6    0.994063 72.41%
#      MGSampler120, QueryScoringAggregator, TemplatePrompts              70.6   71.8   92.9          2.8          1.6    0.994060 71.21%
#            UniformSampler120, MeanPooling, TemplatePrompts              69.8   70.7   91.8          2.8          1.7    0.994070 70.10%
#                 MGSampler120, MeanPooling, TemplatePrompts              68.5   69.7   92.3          2.9          1.7    0.994068 69.20%

# %%
results_analyser.show_accuracy_comparison_plot()

# %%
results_analyser.plot_confused_classes_table("MGSampler120, QueryScoringAggregator, MPVRPrompts")

# %%
results_analyser.plot_calibration_wilcoxon_heatmap()
# Out:
# Friedman Test p-value: 0.0000

# %%
results_analyser.plot_accuracy_mcnemar_heatmap()
# Out:
# Cochran's Q Test p-value: 0.0000
