# %% [markdown]
# # Analyse Results of All Pipeline Combinations

# %%
import sys
from pathlib import Path

project_root = Path("..")
sys.path.append(str(project_root))

# %% [markdown]
# ## Initialise Results Analyser to Calculate Accuracies

# %%
from src.utils.results_analysis import ResultsAnalyser
from src.utils.constants import RESULTS_DIR

results_dir = RESULTS_DIR / "all_combinations_results"

results_analyser = ResultsAnalyser(results_dir)

# %%
results_analyser.print_results_table()
# Out:
#                                                     model  Class Accuracies  Top-1  Top-5  Top-1 Error  Top-5 Error Brier Score    ECE
#          MGSampler16, QueryScoringAggregator, MPVRPrompts              73.2   73.1   95.1          1.4          0.7    0.987951 71.99%
#     UniformSampler16, QueryScoringAggregator, MPVRPrompts              73.1   73.0   95.1          1.4          0.7    0.987945 71.86%
#                     MGSampler16, MeanPooling, MPVRPrompts              72.9   72.9   95.1          1.4          0.7    0.987956 71.78%
#                UniformSampler16, MeanPooling, MPVRPrompts              72.8   72.7   95.1          1.4          0.7    0.987950 71.64%
# UniformSampler16, QueryScoringAggregator, TemplatePrompts              62.9   63.1   86.3          1.5          1.1    0.988547 62.05%
#            UniformSampler16, MeanPooling, TemplatePrompts              62.8   63.0   86.2          1.5          1.1    0.988549 61.94%
#      MGSampler16, QueryScoringAggregator, TemplatePrompts              62.6   62.9   86.2          1.5          1.1    0.988550 61.81%
#                 MGSampler16, MeanPooling, TemplatePrompts              62.5   62.8   86.0          1.5          1.1    0.988552 61.68%

# %%
results_analyser.show_accuracy_comparison_plot()

# %%
results_analyser.plot_confused_classes_table("MGSampler16, QueryScoringAggregator, MPVRPrompts")

# %%
results_analyser.plot_calibration_wilcoxon_heatmap()
# Out:
# Friedman Test p-value: 0.0000

# %%
results_analyser.plot_accuracy_mcnemar_heatmap()
# Out:
# Cochran's Q Test p-value: 0.0000
