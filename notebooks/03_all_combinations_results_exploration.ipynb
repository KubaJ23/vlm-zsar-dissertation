# %% [markdown]
# # Analyse Results of All Pipeline Combinations

# %%
import sys
from pathlib import Path

project_root = Path("..")
sys.path.append(str(project_root))

# %% [markdown]
# ## Initialise Results Analyser to Calculate Accuracies

# %%
from src.utils.results_analysis import ResultsAnalyser
from src.utils.constants import RESULTS_DIR

results_dir = RESULTS_DIR / "all_combinations_results"

results_analyser = ResultsAnalyser(results_dir)

# %%
results_analyser.print_results_table()
# Out:
#                                                     model  Top-1  Top-5
#          MGSampler16, QueryScoringAggregator, MPVRPrompts  73.09  95.08
#     UniformSampler16, QueryScoringAggregator, MPVRPrompts  72.96  95.14
#                     MGSampler16, MeanPooling, MPVRPrompts  72.88  95.08
#                UniformSampler16, MeanPooling, MPVRPrompts  72.75  95.14
# UniformSampler16, QueryScoringAggregator, TemplatePrompts  63.12  86.31
#            UniformSampler16, MeanPooling, TemplatePrompts  63.02  86.23
#      MGSampler16, QueryScoringAggregator, TemplatePrompts  62.89  86.17
#                 MGSampler16, MeanPooling, TemplatePrompts  62.75  85.99

# %%
results_analyser.show_accuracy_comparison_plot()
