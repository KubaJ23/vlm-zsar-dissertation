# %% [markdown]
# # Analyse Results of All Pipeline Combinations

# %%
import sys
from pathlib import Path

project_root = Path("..")
sys.path.append(str(project_root))

# %% [markdown]
# ## Initialise Results Analyser to Calculate Accuracies

# %%
from src.utils.results_analysis import ResultsAnalyser
from src.utils.constants import RESULTS_DIR

results_dir = RESULTS_DIR / "all_combinations_results"

results_analyser = ResultsAnalyser(results_dir)

# %%
results_analyser.print_results_table()
# Out:
#                                                     model  Top-1  Top-5  Top-1 Error  Top-5 Error
#          MGSampler16, QueryScoringAggregator, MPVRPrompts  73.09  95.08         1.41         0.69
#     UniformSampler16, QueryScoringAggregator, MPVRPrompts  72.96  95.14         1.42         0.69
#                     MGSampler16, MeanPooling, MPVRPrompts  72.88  95.08         1.42         0.69
#                UniformSampler16, MeanPooling, MPVRPrompts  72.75  95.14         1.42         0.69
# UniformSampler16, QueryScoringAggregator, TemplatePrompts  63.12  86.31         1.54         1.10
#            UniformSampler16, MeanPooling, TemplatePrompts  63.02  86.23         1.54         1.10
#      MGSampler16, QueryScoringAggregator, TemplatePrompts  62.89  86.17         1.54         1.10
#                 MGSampler16, MeanPooling, TemplatePrompts  62.75  85.99         1.54         1.11

# %%
results_analyser.show_accuracy_comparison_plot()

# %%
results_analyser.plot_cd_diagram()
