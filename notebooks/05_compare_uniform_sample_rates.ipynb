# %% [markdown]
# # Analyse Results of Varying Sample Rates For Sample Methods

# %%
import sys
from pathlib import Path

project_root = Path("..")
sys.path.append(str(project_root))

# %% [markdown]
# ## Initialise Results Analyser to Calculate Accuracies

# %%
from src.utils.results_analysis import ResultsAnalyser
from src.utils.constants import RESULTS_DIR

results_dir = RESULTS_DIR / "varying_uniform_sample_rates"

results_analyser = ResultsAnalyser(results_dir)

# %%
results_analyser.print_results_table()
# Out:
#                                           model  Top-1  Top-5
#  UniformSampler16, MeanPooling, TemplatePrompts  63.02  86.23
#      MGSampler128, MeanPooling, TemplatePrompts  62.89  86.10
# UniformSampler128, MeanPooling, TemplatePrompts  62.83  85.99
#       MGSampler16, MeanPooling, TemplatePrompts  62.75  85.99
#        MGSampler2, MeanPooling, TemplatePrompts  61.30  84.77
#   UniformSampler2, MeanPooling, TemplatePrompts  60.35  84.46

# %%
results_analyser.show_accuracy_comparison_plot()
