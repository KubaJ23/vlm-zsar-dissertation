# %%
import sys
from pathlib import Path

project_root = Path("..")
sys.path.append(str(project_root))

# %%
import pandas as pd

from src.utils.constants import MODEL_RESULTS_CSV

df = pd.read_csv(MODEL_RESULTS_CSV)

# %%
df.head()
# Out:
#                   clip_name                                    clip_path  \
# 0  v_ApplyEyeMakeup_g01_c01  ApplyEyeMakeup\v_ApplyEyeMakeup_g01_c01.avi
# 1  v_ApplyEyeMakeup_g01_c02  ApplyEyeMakeup\v_ApplyEyeMakeup_g01_c02.avi
# 2  v_ApplyEyeMakeup_g01_c03  ApplyEyeMakeup\v_ApplyEyeMakeup_g01_c03.avi
# 3  v_ApplyEyeMakeup_g01_c04  ApplyEyeMakeup\v_ApplyEyeMakeup_g01_c04.avi
# 4  v_ApplyEyeMakeup_g01_c05  ApplyEyeMakeup\v_ApplyEyeMakeup_g01_c05.avi
#
#             label  frame_count  duration_sec   fps  width  height resolution  \
# 0  ApplyEyeMakeup          164          6.56  25.0    320     240    320x240
# 1  ApplyEyeMakeup          123          4.92  25.0    320     240    320x240
# 2  ApplyEyeMakeup          259         10.36  25.0    320     240    320x240
# 3  ApplyEyeMakeup          235          9.40  25.0    320     240    320x240
# 4  ApplyEyeMakeup          296         11.84  25.0    320     240    320x240
#
#   UniformSampler64_MeanPooling_TemplatePrompts  \
# ...

# %%
template_prompts_accuracy = (df['UniformSampler64_MeanPooling_TemplatePrompts'] == df['label']).mean()
print(f"Template prompts accuracy: {template_prompts_accuracy:.2%}")

mpvr_prompts_accuracy = (df['UniformSampler64_MeanPooling_MPVRPrompts'] == df['label']).mean()
print(f"MPVR prompts accuracy: {mpvr_prompts_accuracy:.2%}")
# Out:
# Template prompts accuracy: 62.99%
# MPVR prompts accuracy: 73.12%
