# %% [markdown]
# # Analyse Results of Varying Sample Rates For Sample Methods

# %%
import sys
from pathlib import Path

project_root = Path("..")
sys.path.append(str(project_root))

# %% [markdown]
# ## Initialise Results Analyser to Calculate Accuracies

# %%
from src.utils.results_analysis import ResultsAnalyser
from src.utils.constants import RESULTS_DIR

results_dir = RESULTS_DIR / "varying_sample_rates_and_samplers"

results_analyser = ResultsAnalyser(results_dir)

# %%
results_analyser.print_results_table()
# Out:
#                                           model  Top-1  Top-5  Top-1 Error  Top-5 Error
#  UniformSampler16, MeanPooling, TemplatePrompts  63.02  86.23         1.54         1.10
#      MGSampler128, MeanPooling, TemplatePrompts  62.89  86.10         1.54         1.10
# UniformSampler128, MeanPooling, TemplatePrompts  62.83  85.99         1.54         1.11
#       MGSampler16, MeanPooling, TemplatePrompts  62.75  85.99         1.54         1.11
#        MGSampler2, MeanPooling, TemplatePrompts  61.30  84.77         1.55         1.14
#   UniformSampler2, MeanPooling, TemplatePrompts  60.35  84.46         1.56         1.15

# %%
results_analyser.show_accuracy_comparison_plot()

# %%
results_analyser.plot_cd_diagram()
